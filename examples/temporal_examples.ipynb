# %%
from core.TrajectoryDF import NumPandasTraj as NumTrajDF
from features.temporal_features import TemporalFeatures as temporal
import pandas as pd
import utilities.constants as const
import numpy as np

# %%
# %%time
# Now lets import the gulls.csv and convert it into our
# NumPandasTraj.

gulls = pd.read_csv('./data/gulls.csv')
gulls = NumTrajDF(gulls,
                 latitude='location-lat',
                 longitude='location-long',
                 datetime='timestamp',
                 traj_id='tag-local-identifier',
                 rest_of_columns=[])
gulls.head()
# Out:
# CPU times: user 311 ms, sys: 28.4 ms, total: 340 ms
# Wall time: 349 ms
#                                event-id  visible       lon       lat  \
# DateTime            traj_id
# 2009-05-27 14:00:00 91732    1082620685     True  24.58617  61.24783
# 2009-05-27 20:00:00 91732    1082620686     True  24.58217  61.23267
# 2009-05-28 05:00:00 91732    1082620687     True  24.53133  61.18833
# 2009-05-28 08:00:00 91732    1082620688     True  24.58200  61.23283
# 2009-05-28 14:00:00 91732    1082620689     True  24.58250  61.23267
#
#                             sensor-type individual-taxon-canonical-name  \
# DateTime            traj_id
# 2009-05-27 14:00:00 91732           gps                    Larus fuscus
# 2009-05-27 20:00:00 91732           gps                    Larus fuscus
# 2009-05-28 05:00:00 91732           gps                    Larus fuscus
# 2009-05-28 08:00:00 91732           gps                    Larus fuscus
# 2009-05-28 14:00:00 91732           gps                    Larus fuscus
#
#                             individual-local-identifier  \
# DateTime            traj_id
# 2009-05-27 14:00:00 91732                        91732A
# 2009-05-27 20:00:00 91732                        91732A
# 2009-05-28 05:00:00 91732                        91732A
# 2009-05-28 08:00:00 91732                        91732A
# 2009-05-28 14:00:00 91732                        91732A
#
#                                                                     study-name
# DateTime            traj_id
# 2009-05-27 14:00:00 91732    Navigation experiments in lesser black-backed ...
# 2009-05-27 20:00:00 91732    Navigation experiments in lesser black-backed ...
# 2009-05-28 05:00:00 91732    Navigation experiments in lesser black-backed ...
# 2009-05-28 08:00:00 91732    Navigation experiments in lesser black-backed ...
# 2009-05-28 14:00:00 91732    Navigation experiments in lesser black-backed ...

# %%
# %%time
# Now lets import the geolife_sample.csv and convert it into our
# NumPandasTraj.

pdf = pd.read_csv('./data/geolife_sample.csv')
dataframe = NumTrajDF(pdf,'lat','lon','datetime','id')
dataframe.head()
# Out:
# CPU times: user 533 ms, sys: 23.5 ms, total: 557 ms
# Wall time: 558 ms
#                                    lat         lon
# DateTime            traj_id
# 2008-10-23 16:53:05 1        39.984094  116.319236
# 2008-10-23 16:53:06 1        39.984198  116.319322
# 2008-10-23 05:53:11 1        39.984224  116.319402
# 2008-10-23 05:53:16 1        39.984211  116.319389
# 2008-10-23 05:53:21 1        39.984217  116.319422

# %%
# %%time
# Here, we will calculate the date, time, day of the week and whether
# it is weekend or not in the same cell. Upon running, the library
# always executes within 3-4 seconds. Compared to dask version of this,
# only the time column creation took 7.5 seconds. So this version
# is more efficient in terms of code execution and memory usage.

dataframe = temporal.create_time_column(dataframe)
dataframe = temporal.create_time_of_day_column(dataframe)
dataframe = temporal.create_date_column(dataframe)
dataframe = temporal.create_day_of_week_column(dataframe)
dataframe = temporal.create_weekend_indicator_column(dataframe)
dataframe.head()
# Out:
#                   DateTime traj_id        lat         lon
# 0      2008-10-23 16:53:05       1  39.984094  116.319236
# 1      2008-10-23 16:53:06       1  39.984198  116.319322
# 2      2008-10-23 05:53:11       1  39.984224  116.319402
# 3      2008-10-23 05:53:16       1  39.984211  116.319389
# 4      2008-10-23 05:53:21       1  39.984217  116.319422
# ...                    ...     ...        ...         ...
# 217648 2009-03-19 05:46:02       5  39.999896  116.327290
# 217649 2009-03-19 05:46:07       5  39.999899  116.327352
# 217650 2009-03-19 05:46:12       5  39.999945  116.327394
# 217651 2009-03-19 05:46:17       5  40.000015  116.327433
# 217652 2009-03-19 05:46:37       5  39.999978  116.327460
#
# [217653 rows x 4 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/NumMobility/features/temporal_features.py in create_time_column(dataframe)
#     116         # Then, calculate the result on each separate part in parallel and store it in
#     117         # the result variable which is of type Mapper.
# --> 118         pool = multiprocessing.Pool(len(df_chunks))
#     119         result = pool.map(helpers._time_helper, df_chunks)
#     120
#
# TypeError: object of type 'NoneType' has no len()

# %%
# %%time
# Here, we will calculate the date, time, day of the week and whether
# it is weekend or not in the same cell. Upon running, the library
# always executes within 2 seconds even though this has more number
# of trajectories as compared to geolife_sample.csv.

gulls = temporal.create_time_column(gulls)
gulls = temporal.create_time_of_day_column(gulls)
gulls = temporal.create_date_column(gulls)
gulls = temporal.create_day_of_week_column(gulls)
gulls = temporal.create_weekend_indicator_column(gulls)
gulls.head()
# Out:
#                DateTime traj_id    event-id  visible       lon       lat  \
# 0   2009-05-27 14:00:00   91732  1082620685     True  24.58617  61.24783
# 1   2009-05-27 20:00:00   91732  1082620686     True  24.58217  61.23267
# 2   2009-05-28 05:00:00   91732  1082620687     True  24.53133  61.18833
# 3   2009-05-28 08:00:00   91732  1082620688     True  24.58200  61.23283
# 4   2009-05-28 14:00:00   91732  1082620689     True  24.58250  61.23267
# ..                  ...     ...         ...      ...       ...       ...
# 894 2010-01-15 08:00:00   91732  1082621579     True  33.85017  -1.17550
# 895 2010-01-15 14:00:00   91732  1082621580     True  33.90083  -1.20833
# 896 2010-01-15 20:00:00   91732  1082621581     True  33.83367  -1.14567
# 897 2010-01-16 05:00:00   91732  1082621582     True  33.86633  -1.17167
# 898 2010-01-16 08:00:00   91732  1082621583     True  33.86017  -1.16883
#
#     sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 0           gps                    Larus fuscus                      91732A
# 1           gps                    Larus fuscus                      91732A
# 2           gps                    Larus fuscus                      91732A
# 3           gps                    Larus fuscus                      91732A
# 4           gps                    Larus fuscus                      91732A
# ..          ...                             ...                         ...
# 894         gps                    Larus fuscus                      91732A
# 895         gps                    Larus fuscus                      91732A
# 896         gps                    Larus fuscus                      91732A
# 897         gps                    Larus fuscus                      91732A
# 898         gps                    Larus fuscus                      91732A
#
#                                             study-name
# 0    Navigation experiments in lesser black-backed ...
# 1    Navigation experiments in lesser black-backed ...
# 2    Navigation experiments in lesser black-backed ...
# 3    Navigation experiments in lesser black-backed ...
# 4    Navigation experiments in lesser black-backed ...
# ..                                                 ...
# 894  Navigation experiments in lesser black-backed ...
# 895  Navigation experiments in lesser black-backed ...
# 896  Navigation experiments in lesser black-backed ...
# 897  Navigation experiments in lesser black-backed ...
# 898  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 899  2010-01-16 14:00:00   91732  1082621584     True  33.90317  -1.20867
# 900  2010-01-16 20:00:00   91732  1082621585     True  33.83000  -1.15583
# 901  2010-01-17 05:00:00   91732  1082621586     True  33.85133  -1.18350
# 902  2010-01-17 08:00:00   91732  1082621587     True  33.85733  -1.16567
# 903  2010-01-17 14:00:00   91732  1082621588     True  33.90083  -1.20833
# ...                  ...     ...         ...      ...       ...       ...
# 1793 2010-08-30 06:00:00   91732  1082622478     True  19.53867  54.75600
# 1794 2010-08-30 09:00:00   91732  1082622479     True  19.60417  54.75267
# 1795 2010-08-30 15:00:00   91732  1082622480     True  19.23583  54.51033
# 1796 2010-08-31 06:00:00   91732  1082622481     True  19.25650  54.59783
# 1797 2010-08-31 09:00:00   91732  1082622482     True  19.24367  54.59050
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 899          gps                    Larus fuscus                      91732A
# 900          gps                    Larus fuscus                      91732A
# 901          gps                    Larus fuscus                      91732A
# 902          gps                    Larus fuscus                      91732A
# 903          gps                    Larus fuscus                      91732A
# ...          ...                             ...                         ...
# 1793         gps                    Larus fuscus                      91732A
# 1794         gps                    Larus fuscus                      91732A
# 1795         gps                    Larus fuscus                      91732A
# 1796         gps                    Larus fuscus                      91732A
# 1797         gps                    Larus fuscus                      91732A
#
#                                              study-name
# 899   Navigation experiments in lesser black-backed ...
# 900   Navigation experiments in lesser black-backed ...
# 901   Navigation experiments in lesser black-backed ...
# 902   Navigation experiments in lesser black-backed ...
# 903   Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 1793  Navigation experiments in lesser black-backed ...
# 1794  Navigation experiments in lesser black-backed ...
# 1795  Navigation experiments in lesser black-backed ...
# 1796  Navigation experiments in lesser black-backed ...
# 1797  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 1798 2010-08-31 15:00:00   91732  1082622483     True  19.30167  54.28467
# 1799 2010-08-31 21:00:00   91732  1082622484     True  19.04283  54.48200
# 1800 2010-09-01 06:00:00   91732  1082622485     True  19.46033  54.39150
# 1801 2010-09-01 09:00:00   91732  1082622486     True  19.29917  54.42933
# 1802 2010-09-01 15:00:00   91732  1082622487     True  20.35367  52.10683
# ...                  ...     ...         ...      ...       ...       ...
# 2692 2009-08-23 00:14:00   91734   150723495     True  24.21933  61.17883
# 2693 2009-08-23 00:20:00   91734   150723496     True  24.24600  61.17783
# 2694 2009-08-23 05:00:00   91734  1082697791     True  24.28850  61.20000
# 2695 2009-08-23 08:00:00   91734  1082697792     True  24.30333  61.20000
# 2696 2009-08-23 14:00:00   91734  1082697793     True  24.21933  61.17883
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 1798         gps                    Larus fuscus                      91732A
# 1799         gps                    Larus fuscus                      91732A
# 1800         gps                    Larus fuscus                      91732A
# 1801         gps                    Larus fuscus                      91732A
# 1802         gps                    Larus fuscus                      91732A
# ...          ...                             ...                         ...
# 2692         gps                    Larus fuscus                      91734A
# 2693         gps                    Larus fuscus                      91734A
# 2694         gps                    Larus fuscus                      91734A
# 2695         gps                    Larus fuscus                      91734A
# 2696         gps                    Larus fuscus                      91734A
#
#                                              study-name
# 1798  Navigation experiments in lesser black-backed ...
# 1799  Navigation experiments in lesser black-backed ...
# 1800  Navigation experiments in lesser black-backed ...
# 1801  Navigation experiments in lesser black-backed ...
# 1802  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 2692  Navigation experiments in lesser black-backed ...
# 2693  Navigation experiments in lesser black-backed ...
# 2694  Navigation experiments in lesser black-backed ...
# 2695  Navigation experiments in lesser black-backed ...
# 2696  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 2697 2009-08-23 20:00:00   91734  1082697794     True  24.24600  61.17783
# 2698 2009-08-24 00:05:00   91734   150723497     True  24.31533  61.24133
# 2699 2009-08-24 00:08:00   91734   150723498     True  24.29850  61.20367
# 2700 2009-08-24 00:14:00   91734   150723499     True  24.29933  60.40800
# 2701 2009-08-24 00:20:00   91734   150723500     True  24.22800  59.95133
# ...                  ...     ...         ...      ...       ...       ...
# 3591 2009-08-05 08:00:00   91737  1082690148     True  22.51400  63.60067
# 3592 2009-08-05 14:00:00   91737  1082690149     True  22.50067  63.64167
# 3593 2009-08-05 20:00:00   91737  1082690150     True  22.50033  63.64183
# 3594 2009-08-06 05:00:00   91737  1082690151     True  22.50067  63.64150
# 3595 2009-08-06 08:00:00   91737  1082690152     True  22.56817  63.45717
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 2697         gps                    Larus fuscus                      91734A
# 2698         gps                    Larus fuscus                      91734A
# 2699         gps                    Larus fuscus                      91734A
# 2700         gps                    Larus fuscus                      91734A
# 2701         gps                    Larus fuscus                      91734A
# ...          ...                             ...                         ...
# 3591         gps                    Larus fuscus                      91737A
# 3592         gps                    Larus fuscus                      91737A
# 3593         gps                    Larus fuscus                      91737A
# 3594         gps                    Larus fuscus                      91737A
# 3595         gps                    Larus fuscus                      91737A
#
#                                              study-name
# 2697  Navigation experiments in lesser black-backed ...
# 2698  Navigation experiments in lesser black-backed ...
# 2699  Navigation experiments in lesser black-backed ...
# 2700  Navigation experiments in lesser black-backed ...
# 2701  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 3591  Navigation experiments in lesser black-backed ...
# 3592  Navigation experiments in lesser black-backed ...
# 3593  Navigation experiments in lesser black-backed ...
# 3594  Navigation experiments in lesser black-backed ...
# 3595  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 3596 2009-08-06 14:00:00   91737  1082690153     True  22.50017  63.64183
# 3597 2009-08-06 20:00:00   91737  1082690154     True  22.50050  63.64183
# 3598 2009-08-07 05:00:00   91737  1082690155     True  22.50067  63.64150
# 3599 2009-08-07 08:00:00   91737  1082690156     True  22.50067  63.64150
# 3600 2009-08-07 14:00:00   91737  1082690157     True  22.55100  63.53133
# ...                  ...     ...         ...      ...       ...       ...
# 4490 2010-03-29 19:00:00   91737  1082691047     True  42.44133  17.05883
# 4491 2010-03-30 04:00:00   91737  1082691048     True  42.54617  16.98967
# 4492 2010-03-30 07:00:00   91737  1082691049     True  42.54650  16.99067
# 4493 2010-03-30 13:00:00   91737  1082691050     True  42.54250  16.97467
# 4494 2010-03-30 19:00:00   91737  1082691051     True  42.53567  16.94433
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 3596         gps                    Larus fuscus                      91737A
# 3597         gps                    Larus fuscus                      91737A
# 3598         gps                    Larus fuscus                      91737A
# 3599         gps                    Larus fuscus                      91737A
# 3600         gps                    Larus fuscus                      91737A
# ...          ...                             ...                         ...
# 4490         gps                    Larus fuscus                      91737A
# 4491         gps                    Larus fuscus                      91737A
# 4492         gps                    Larus fuscus                      91737A
# 4493         gps                    Larus fuscus                      91737A
# 4494         gps                    Larus fuscus                      91737A
#
#                                              study-name
# 3596  Navigation experiments in lesser black-backed ...
# 3597  Navigation experiments in lesser black-backed ...
# 3598  Navigation experiments in lesser black-backed ...
# 3599  Navigation experiments in lesser black-backed ...
# 3600  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 4490  Navigation experiments in lesser black-backed ...
# 4491  Navigation experiments in lesser black-backed ...
# 4492  Navigation experiments in lesser black-backed ...
# 4493  Navigation experiments in lesser black-backed ...
# 4494  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 4495 2010-03-31 04:00:00   91737  1082691052     True  42.54633  16.99617
# 4496 2010-03-31 07:00:00   91737  1082691053     True  42.53950  16.97250
# 4497 2010-03-31 13:00:00   91737  1082691054     True  42.54033  16.97667
# 4498 2010-03-31 19:00:00   91737  1082691055     True  42.52533  16.98383
# 4499 2010-04-01 04:00:00   91737  1082691056     True  42.43333  16.98233
# ...                  ...     ...         ...      ...       ...       ...
# 5389 2009-08-28 05:00:00   91739  1082608003     True  28.39267  60.31967
# 5390 2009-08-28 08:00:00   91739  1082608004     True  28.33583  60.03350
# 5391 2009-08-28 14:00:00   91739  1082608005     True  28.27133  60.27600
# 5392 2009-08-28 20:00:00   91739  1082608006     True  27.95650  60.24367
# 5393 2009-08-29 05:00:00   91739  1082608007     True  28.21100  60.34200
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 4495         gps                    Larus fuscus                      91737A
# 4496         gps                    Larus fuscus                      91737A
# 4497         gps                    Larus fuscus                      91737A
# 4498         gps                    Larus fuscus                      91737A
# 4499         gps                    Larus fuscus                      91737A
# ...          ...                             ...                         ...
# 5389         gps                    Larus fuscus                      91739A
# 5390         gps                    Larus fuscus                      91739A
# 5391         gps                    Larus fuscus                      91739A
# 5392         gps                    Larus fuscus                      91739A
# 5393         gps                    Larus fuscus                      91739A
#
#                                              study-name
# 4495  Navigation experiments in lesser black-backed ...
# 4496  Navigation experiments in lesser black-backed ...
# 4497  Navigation experiments in lesser black-backed ...
# 4498  Navigation experiments in lesser black-backed ...
# 4499  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 5389  Navigation experiments in lesser black-backed ...
# 5390  Navigation experiments in lesser black-backed ...
# 5391  Navigation experiments in lesser black-backed ...
# 5392  Navigation experiments in lesser black-backed ...
# 5393  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 5394 2009-08-29 08:00:00   91739  1082608008     True  28.43500  60.26017
# 5395 2009-08-29 14:00:00   91739  1082608009     True  27.95767  60.24717
# 5396 2009-08-29 20:00:00   91739  1082608010     True  27.95667  60.24033
# 5397 2009-08-30 05:00:00   91739  1082608011     True  28.34067  60.18617
# 5398 2009-08-30 08:00:00   91739  1082608012     True  28.33983  60.19733
# ...                  ...     ...         ...      ...       ...       ...
# 6288 2010-04-22 05:00:00   91739  1082608902     True  32.64600  29.05717
# 6289 2010-04-22 08:00:00   91739  1082608903     True  32.64517  29.05983
# 6290 2010-04-22 14:00:00   91739  1082608904     True  32.64567  29.05733
# 6291 2010-04-22 20:00:00   91739  1082608905     True  32.64933  29.05267
# 6292 2010-04-23 05:00:00   91739  1082608906     True  32.64817  29.05317
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 5394         gps                    Larus fuscus                      91739A
# 5395         gps                    Larus fuscus                      91739A
# 5396         gps                    Larus fuscus                      91739A
# 5397         gps                    Larus fuscus                      91739A
# 5398         gps                    Larus fuscus                      91739A
# ...          ...                             ...                         ...
# 6288         gps                    Larus fuscus                      91739A
# 6289         gps                    Larus fuscus                      91739A
# 6290         gps                    Larus fuscus                      91739A
# 6291         gps                    Larus fuscus                      91739A
# 6292         gps                    Larus fuscus                      91739A
#
#                                              study-name
# 5394  Navigation experiments in lesser black-backed ...
# 5395  Navigation experiments in lesser black-backed ...
# 5396  Navigation experiments in lesser black-backed ...
# 5397  Navigation experiments in lesser black-backed ...
# 5398  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 6288  Navigation experiments in lesser black-backed ...
# 6289  Navigation experiments in lesser black-backed ...
# 6290  Navigation experiments in lesser black-backed ...
# 6291  Navigation experiments in lesser black-backed ...
# 6292  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 6293 2010-04-23 08:00:00   91739  1082608907     True  32.64833  29.05350
# 6294 2010-04-23 14:00:00   91739  1082608908     True  32.64767  29.05567
# 6295 2010-04-23 20:00:00   91739  1082608909     True  32.64817  29.05300
# 6296 2010-04-24 05:00:00   91739  1082608910     True  32.64833  29.05300
# 6297 2010-04-24 08:00:00   91739  1082608911     True  32.64883  29.05283
# ...                  ...     ...         ...      ...       ...       ...
# 7187 2010-12-07 20:00:00   91739  1082609801     True  32.39417  29.58717
# 7188 2010-12-08 05:00:00   91739  1082609802     True  32.39550  29.58783
# 7189 2010-12-08 08:00:00   91739  1082609803     True  32.39667  29.58750
# 7190 2010-12-08 14:00:00   91739  1082609804     True  32.40667  29.56617
# 7191 2010-12-08 20:00:00   91739  1082609805     True  32.39467  29.58767
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 6293         gps                    Larus fuscus                      91739A
# 6294         gps                    Larus fuscus                      91739A
# 6295         gps                    Larus fuscus                      91739A
# 6296         gps                    Larus fuscus                      91739A
# 6297         gps                    Larus fuscus                      91739A
# ...          ...                             ...                         ...
# 7187         gps                    Larus fuscus                      91739A
# 7188         gps                    Larus fuscus                      91739A
# 7189         gps                    Larus fuscus                      91739A
# 7190         gps                    Larus fuscus                      91739A
# 7191         gps                    Larus fuscus                      91739A
#
#                                              study-name
# 6293  Navigation experiments in lesser black-backed ...
# 6294  Navigation experiments in lesser black-backed ...
# 6295  Navigation experiments in lesser black-backed ...
# 6296  Navigation experiments in lesser black-backed ...
# 6297  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 7187  Navigation experiments in lesser black-backed ...
# 7188  Navigation experiments in lesser black-backed ...
# 7189  Navigation experiments in lesser black-backed ...
# 7190  Navigation experiments in lesser black-backed ...
# 7191  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 7192 2010-12-09 05:00:00   91739  1082609806     True  32.47067  29.59233
# 7193 2010-12-09 08:00:00   91739  1082609807     True  32.40900  29.56617
# 7194 2010-12-09 14:00:00   91739  1082609808     True  32.40783  29.56683
# 7195 2010-12-09 20:00:00   91739  1082609809     True  32.38033  29.56933
# 7196 2010-12-10 05:00:00   91739  1082609810     True  32.40800  29.56700
# ...                  ...     ...         ...      ...       ...       ...
# 8086 2009-09-27 14:00:00   91740  1082653513     True  29.91717  61.98550
# 8087 2009-05-27 14:00:00   91741  1082711073     True  24.59733  61.20183
# 8088 2009-05-27 20:00:00   91741  1082711074     True  24.59733  61.20183
# 8089 2009-05-28 05:00:00   91741  1082711075     True  24.59567  61.20183
# 8090 2009-05-28 08:00:00   91741  1082711076     True  24.59750  61.20183
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 7192         gps                    Larus fuscus                      91739A
# 7193         gps                    Larus fuscus                      91739A
# 7194         gps                    Larus fuscus                      91739A
# 7195         gps                    Larus fuscus                      91739A
# 7196         gps                    Larus fuscus                      91739A
# ...          ...                             ...                         ...
# 8086         gps                    Larus fuscus                      91740A
# 8087         gps                    Larus fuscus                      91741A
# 8088         gps                    Larus fuscus                      91741A
# 8089         gps                    Larus fuscus                      91741A
# 8090         gps                    Larus fuscus                      91741A
#
#                                              study-name
# 7192  Navigation experiments in lesser black-backed ...
# 7193  Navigation experiments in lesser black-backed ...
# 7194  Navigation experiments in lesser black-backed ...
# 7195  Navigation experiments in lesser black-backed ...
# 7196  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 8086  Navigation experiments in lesser black-backed ...
# 8087  Navigation experiments in lesser black-backed ...
# 8088  Navigation experiments in lesser black-backed ...
# 8089  Navigation experiments in lesser black-backed ...
# 8090  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 8091 2009-05-28 14:00:00   91741  1082711077     True  24.59733  61.20200
# 8092 2009-05-28 20:00:00   91741  1082711078     True  24.59733  61.20183
# 8093 2009-05-29 05:00:00   91741  1082711079     True  24.58250  61.18150
# 8094 2009-05-29 08:00:00   91741  1082711080     True  24.59733  61.20183
# 8095 2009-05-29 14:00:00   91741  1082711081     True  24.59717  61.20183
# ...                  ...     ...         ...      ...       ...       ...
# 8985 2009-09-30 14:00:00   91742  1082611367     True  24.62350  59.98550
# 8986 2009-09-30 20:00:00   91742  1082611368     True  24.62333  59.98500
# 8987 2009-10-01 05:00:00   91742  1082611369     True  24.19883  59.80283
# 8988 2009-10-01 08:00:00   91742  1082611370     True  23.48817  59.67950
# 8989 2009-10-01 15:00:00   91742  1082611371     True  20.31250  58.28850
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 8091         gps                    Larus fuscus                      91741A
# 8092         gps                    Larus fuscus                      91741A
# 8093         gps                    Larus fuscus                      91741A
# 8094         gps                    Larus fuscus                      91741A
# 8095         gps                    Larus fuscus                      91741A
# ...          ...                             ...                         ...
# 8985         gps                    Larus fuscus                      91742A
# 8986         gps                    Larus fuscus                      91742A
# 8987         gps                    Larus fuscus                      91742A
# 8988         gps                    Larus fuscus                      91742A
# 8989         gps                    Larus fuscus                      91742A
#
#                                              study-name
# 8091  Navigation experiments in lesser black-backed ...
# 8092  Navigation experiments in lesser black-backed ...
# 8093  Navigation experiments in lesser black-backed ...
# 8094  Navigation experiments in lesser black-backed ...
# 8095  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 8985  Navigation experiments in lesser black-backed ...
# 8986  Navigation experiments in lesser black-backed ...
# 8987  Navigation experiments in lesser black-backed ...
# 8988  Navigation experiments in lesser black-backed ...
# 8989  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                 DateTime traj_id    event-id  visible       lon       lat  \
# 8990 2009-10-01 21:00:00   91742  1082611372     True  18.82167  57.37383
# 8991 2009-10-02 09:00:00   91742  1082611373     True  19.85667  56.18850
# 8992 2009-10-02 15:00:00   91742  1082611374     True  20.99817  55.26517
# 8993 2009-10-02 21:00:00   91742  1082611375     True  21.02883  55.30967
# 8994 2009-10-03 06:00:00   91742  1082611376     True  20.90883  55.21817
# ...                  ...     ...         ...      ...       ...       ...
# 9884 2009-09-01 09:00:00   91745  1082610443     True   9.46367  54.13900
# 9885 2009-09-01 15:00:00   91745  1082610444     True   9.57000  54.09333
# 9886 2009-09-01 21:00:00   91745  1082610445     True   9.36283  54.14917
# 9887 2009-09-02 06:00:00   91745  1082610446     True   9.57400  54.09433
# 9888 2009-09-02 09:00:00   91745  1082610447     True   9.57317  54.05433
#
#      sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 8990         gps                    Larus fuscus                      91742A
# 8991         gps                    Larus fuscus                      91742A
# 8992         gps                    Larus fuscus                      91742A
# 8993         gps                    Larus fuscus                      91742A
# 8994         gps                    Larus fuscus                      91742A
# ...          ...                             ...                         ...
# 9884         gps                    Larus fuscus                      91745A
# 9885         gps                    Larus fuscus                      91745A
# 9886         gps                    Larus fuscus                      91745A
# 9887         gps                    Larus fuscus                      91745A
# 9888         gps                    Larus fuscus                      91745A
#
#                                              study-name
# 8990  Navigation experiments in lesser black-backed ...
# 8991  Navigation experiments in lesser black-backed ...
# 8992  Navigation experiments in lesser black-backed ...
# 8993  Navigation experiments in lesser black-backed ...
# 8994  Navigation experiments in lesser black-backed ...
# ...                                                 ...
# 9884  Navigation experiments in lesser black-backed ...
# 9885  Navigation experiments in lesser black-backed ...
# 9886  Navigation experiments in lesser black-backed ...
# 9887  Navigation experiments in lesser black-backed ...
# 9888  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 9889  2009-09-02 15:00:00   91745  1082610448     True   9.73033  53.99000
# 9890  2009-09-02 21:00:00   91745  1082610449     True   9.43433  53.88833
# 9891  2009-09-03 06:00:00   91745  1082610450     True   9.62950  53.91700
# 9892  2009-09-03 09:00:00   91745  1082610451     True   9.84517  53.98033
# 9893  2009-09-03 15:00:00   91745  1082610452     True  10.39650  53.77950
# ...                   ...     ...         ...      ...       ...       ...
# 10783 2009-08-10 20:00:00   91747  1082617211     True  29.25867  62.37183
# 10784 2009-08-11 08:00:00   91747  1082617212     True  29.24383  62.40717
# 10785 2009-08-11 14:00:00   91747  1082617213     True  29.24100  62.39767
# 10786 2009-08-11 20:00:00   91747  1082617214     True  29.25883  62.37183
# 10787 2009-08-12 05:00:00   91747  1082617215     True  29.22817  62.40733
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 9889          gps                    Larus fuscus                      91745A
# 9890          gps                    Larus fuscus                      91745A
# 9891          gps                    Larus fuscus                      91745A
# 9892          gps                    Larus fuscus                      91745A
# 9893          gps                    Larus fuscus                      91745A
# ...           ...                             ...                         ...
# 10783         gps                    Larus fuscus                      91747A
# 10784         gps                    Larus fuscus                      91747A
# 10785         gps                    Larus fuscus                      91747A
# 10786         gps                    Larus fuscus                      91747A
# 10787         gps                    Larus fuscus                      91747A
#
#                                               study-name
# 9889   Navigation experiments in lesser black-backed ...
# 9890   Navigation experiments in lesser black-backed ...
# 9891   Navigation experiments in lesser black-backed ...
# 9892   Navigation experiments in lesser black-backed ...
# 9893   Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 10783  Navigation experiments in lesser black-backed ...
# 10784  Navigation experiments in lesser black-backed ...
# 10785  Navigation experiments in lesser black-backed ...
# 10786  Navigation experiments in lesser black-backed ...
# 10787  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 10788 2009-08-12 08:00:00   91747  1082617216     True  29.22883  62.40783
# 10789 2009-08-12 14:00:00   91747  1082617217     True  29.25883  62.37200
# 10790 2009-08-12 20:00:00   91747  1082617218     True  29.25867  62.37200
# 10791 2009-08-13 05:00:00   91747  1082617219     True  29.22800  62.40733
# 10792 2009-08-13 08:00:00   91747  1082617220     True  29.22817  62.40733
# ...                   ...     ...         ...      ...       ...       ...
# 11682 2009-09-10 14:00:00   91749  1082634975     True  28.63283  62.74450
# 11683 2009-09-10 20:00:00   91749  1082634976     True  28.61200  62.73800
# 11684 2009-09-11 05:00:00   91749  1082634977     True  28.46950  62.73500
# 11685 2009-09-11 08:00:00   91749  1082634978     True  28.44183  62.73467
# 11686 2009-09-11 14:00:00   91749  1082634979     True  28.46983  62.73633
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 10788         gps                    Larus fuscus                      91747A
# 10789         gps                    Larus fuscus                      91747A
# 10790         gps                    Larus fuscus                      91747A
# 10791         gps                    Larus fuscus                      91747A
# 10792         gps                    Larus fuscus                      91747A
# ...           ...                             ...                         ...
# 11682         gps                    Larus fuscus                      91749A
# 11683         gps                    Larus fuscus                      91749A
# 11684         gps                    Larus fuscus                      91749A
# 11685         gps                    Larus fuscus                      91749A
# 11686         gps                    Larus fuscus                      91749A
#
#                                               study-name
# 10788  Navigation experiments in lesser black-backed ...
# 10789  Navigation experiments in lesser black-backed ...
# 10790  Navigation experiments in lesser black-backed ...
# 10791  Navigation experiments in lesser black-backed ...
# 10792  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 11682  Navigation experiments in lesser black-backed ...
# 11683  Navigation experiments in lesser black-backed ...
# 11684  Navigation experiments in lesser black-backed ...
# 11685  Navigation experiments in lesser black-backed ...
# 11686  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 11687 2009-09-11 20:00:00   91749  1082634980     True  28.61583  62.73600
# 11688 2009-09-12 05:00:00   91749  1082634981     True  28.47033  62.73600
# 11689 2009-09-12 08:00:00   91749  1082634982     True  28.45217  62.74317
# 11690 2009-09-12 14:00:00   91749  1082634983     True  28.46983  62.73600
# 11691 2009-09-12 20:00:00   91749  1082634984     True  28.60967  62.73800
# ...                   ...     ...         ...      ...       ...       ...
# 12581 2009-10-13 20:00:00   91751  1082634287     True  29.95417  58.61100
# 12582 2009-10-14 05:00:00   91751  1082634288     True  29.98667  58.62717
# 12583 2009-10-14 08:00:00   91751  1082634289     True  29.85583  58.75483
# 12584 2009-10-14 14:00:00   91751  1082634290     True  29.95617  58.60633
# 12585 2009-10-14 20:00:00   91751  1082634291     True  29.94567  58.62250
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 11687         gps                    Larus fuscus                      91749A
# 11688         gps                    Larus fuscus                      91749A
# 11689         gps                    Larus fuscus                      91749A
# 11690         gps                    Larus fuscus                      91749A
# 11691         gps                    Larus fuscus                      91749A
# ...           ...                             ...                         ...
# 12581         gps                    Larus fuscus                      91751A
# 12582         gps                    Larus fuscus                      91751A
# 12583         gps                    Larus fuscus                      91751A
# 12584         gps                    Larus fuscus                      91751A
# 12585         gps                    Larus fuscus                      91751A
#
#                                               study-name
# 11687  Navigation experiments in lesser black-backed ...
# 11688  Navigation experiments in lesser black-backed ...
# 11689  Navigation experiments in lesser black-backed ...
# 11690  Navigation experiments in lesser black-backed ...
# 11691  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 12581  Navigation experiments in lesser black-backed ...
# 12582  Navigation experiments in lesser black-backed ...
# 12583  Navigation experiments in lesser black-backed ...
# 12584  Navigation experiments in lesser black-backed ...
# 12585  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 12586 2009-10-15 05:00:00   91751  1082634292     True  29.93100  58.63417
# 12587 2009-10-15 08:00:00   91751  1082634293     True  29.97183  58.59817
# 12588 2009-10-15 14:00:00   91751  1082634294     True  29.98767  58.58567
# 12589 2009-10-15 20:00:00   91751  1082634295     True  29.94567  58.61417
# 12590 2009-10-16 05:00:00   91751  1082634296     True  29.97117  58.61467
# ...                   ...     ...         ...      ...       ...       ...
# 13480 2010-01-28 19:00:00   91752  1082593508     True  38.72967   7.94433
# 13481 2010-01-29 04:00:00   91752  1082593509     True  38.73050   7.94500
# 13482 2010-01-29 07:00:00   91752  1082593510     True  38.72983   7.94433
# 13483 2010-01-29 13:00:00   91752  1082593511     True  38.73000   7.94450
# 13484 2010-01-29 19:00:00   91752  1082593512     True  38.72983   7.94433
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 12586         gps                    Larus fuscus                      91751A
# 12587         gps                    Larus fuscus                      91751A
# 12588         gps                    Larus fuscus                      91751A
# 12589         gps                    Larus fuscus                      91751A
# 12590         gps                    Larus fuscus                      91751A
# ...           ...                             ...                         ...
# 13480         gps                    Larus fuscus                      91752A
# 13481         gps                    Larus fuscus                      91752A
# 13482         gps                    Larus fuscus                      91752A
# 13483         gps                    Larus fuscus                      91752A
# 13484         gps                    Larus fuscus                      91752A
#
#                                               study-name
# 12586  Navigation experiments in lesser black-backed ...
# 12587  Navigation experiments in lesser black-backed ...
# 12588  Navigation experiments in lesser black-backed ...
# 12589  Navigation experiments in lesser black-backed ...
# 12590  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 13480  Navigation experiments in lesser black-backed ...
# 13481  Navigation experiments in lesser black-backed ...
# 13482  Navigation experiments in lesser black-backed ...
# 13483  Navigation experiments in lesser black-backed ...
# 13484  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon      lat  \
# 13485 2010-01-30 04:00:00   91752  1082593513     True  38.73000  7.94450
# 13486 2010-01-30 07:00:00   91752  1082593514     True  38.73000  7.94450
# 13487 2010-01-30 13:00:00   91752  1082593515     True  38.72983  7.94450
# 13488 2010-01-30 19:00:00   91752  1082593516     True  38.72917  7.94367
# 13489 2010-01-31 04:00:00   91752  1082593517     True  38.74550  7.90000
# ...                   ...     ...         ...      ...       ...      ...
# 14379 2010-09-11 07:00:00   91752  1082594407     True  38.79550  7.97217
# 14380 2010-09-11 13:00:00   91752  1082594408     True  38.86200  8.06617
# 14381 2010-09-11 19:00:00   91752  1082594409     True  38.86267  8.06700
# 14382 2010-09-12 04:00:00   91752  1082594410     True  38.80117  8.07933
# 14383 2010-09-12 07:00:00   91752  1082594411     True  38.89067  8.02683
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 13485         gps                    Larus fuscus                      91752A
# 13486         gps                    Larus fuscus                      91752A
# 13487         gps                    Larus fuscus                      91752A
# 13488         gps                    Larus fuscus                      91752A
# 13489         gps                    Larus fuscus                      91752A
# ...           ...                             ...                         ...
# 14379         gps                    Larus fuscus                      91752A
# 14380         gps                    Larus fuscus                      91752A
# 14381         gps                    Larus fuscus                      91752A
# 14382         gps                    Larus fuscus                      91752A
# 14383         gps                    Larus fuscus                      91752A
#
#                                               study-name
# 13485  Navigation experiments in lesser black-backed ...
# 13486  Navigation experiments in lesser black-backed ...
# 13487  Navigation experiments in lesser black-backed ...
# 13488  Navigation experiments in lesser black-backed ...
# 13489  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 14379  Navigation experiments in lesser black-backed ...
# 14380  Navigation experiments in lesser black-backed ...
# 14381  Navigation experiments in lesser black-backed ...
# 14382  Navigation experiments in lesser black-backed ...
# 14383  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon      lat  \
# 14384 2010-09-12 13:00:00   91752  1082594412     True  38.86217  8.06600
# 14385 2010-09-12 19:00:00   91752  1082594413     True  38.86333  8.06800
# 14386 2010-09-13 04:00:00   91752  1082594414     True  38.86467  8.06667
# 14387 2010-09-13 07:00:00   91752  1082594415     True  38.84117  8.05167
# 14388 2010-09-13 13:00:00   91752  1082594416     True  38.86217  8.06600
# ...                   ...     ...         ...      ...       ...      ...
# 15278 2011-04-24 04:00:00   91752  1082595306     True  38.75950  8.00533
# 15279 2011-04-24 07:00:00   91752  1082595307     True  38.80750  8.11250
# 15280 2011-04-24 13:00:00   91752  1082595308     True  38.74783  7.98983
# 15281 2011-04-24 19:00:00   91752  1082595309     True  38.82350  7.87083
# 15282 2011-04-25 04:00:00   91752  1082595310     True  38.83150  8.06917
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 14384         gps                    Larus fuscus                      91752A
# 14385         gps                    Larus fuscus                      91752A
# 14386         gps                    Larus fuscus                      91752A
# 14387         gps                    Larus fuscus                      91752A
# 14388         gps                    Larus fuscus                      91752A
# ...           ...                             ...                         ...
# 15278         gps                    Larus fuscus                      91752A
# 15279         gps                    Larus fuscus                      91752A
# 15280         gps                    Larus fuscus                      91752A
# 15281         gps                    Larus fuscus                      91752A
# 15282         gps                    Larus fuscus                      91752A
#
#                                               study-name
# 14384  Navigation experiments in lesser black-backed ...
# 14385  Navigation experiments in lesser black-backed ...
# 14386  Navigation experiments in lesser black-backed ...
# 14387  Navigation experiments in lesser black-backed ...
# 14388  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 15278  Navigation experiments in lesser black-backed ...
# 15279  Navigation experiments in lesser black-backed ...
# 15280  Navigation experiments in lesser black-backed ...
# 15281  Navigation experiments in lesser black-backed ...
# 15282  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon      lat  \
# 15283 2011-04-25 07:00:00   91752  1082595311     True  38.72917  7.94383
# 15284 2011-04-25 13:00:00   91752  1082595312     True  38.82783  7.85967
# 15285 2011-04-25 19:00:00   91752  1082595313     True  38.75233  7.90817
# 15286 2011-04-26 04:00:00   91752  1082595314     True  38.75217  8.01533
# 15287 2011-04-26 07:00:00   91752  1082595315     True  38.86033  8.05733
# ...                   ...     ...         ...      ...       ...      ...
# 16177 2011-12-05 04:00:00   91752  1082596205     True  38.85900  8.06350
# 16178 2011-12-05 07:00:00   91752  1082596206     True  38.85883  8.06367
# 16179 2011-12-05 13:00:00   91752  1082596207     True  38.85883  8.06383
# 16180 2011-12-05 19:00:00   91752  1082596208     True  38.78083  8.07400
# 16181 2011-12-06 04:00:00   91752  1082596209     True  38.80950  8.09683
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 15283         gps                    Larus fuscus                      91752A
# 15284         gps                    Larus fuscus                      91752A
# 15285         gps                    Larus fuscus                      91752A
# 15286         gps                    Larus fuscus                      91752A
# 15287         gps                    Larus fuscus                      91752A
# ...           ...                             ...                         ...
# 16177         gps                    Larus fuscus                      91752A
# 16178         gps                    Larus fuscus                      91752A
# 16179         gps                    Larus fuscus                      91752A
# 16180         gps                    Larus fuscus                      91752A
# 16181         gps                    Larus fuscus                      91752A
#
#                                               study-name
# 15283  Navigation experiments in lesser black-backed ...
# 15284  Navigation experiments in lesser black-backed ...
# 15285  Navigation experiments in lesser black-backed ...
# 15286  Navigation experiments in lesser black-backed ...
# 15287  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 16177  Navigation experiments in lesser black-backed ...
# 16178  Navigation experiments in lesser black-backed ...
# 16179  Navigation experiments in lesser black-backed ...
# 16180  Navigation experiments in lesser black-backed ...
# 16181  Navigation experiments in lesser black-backed ...
#
# [899 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon      lat  \
# 16182 2011-12-06 07:00:00   91752  1082596210     True  38.81067  8.09117
# 16183 2011-12-06 13:00:00   91752  1082596211     True  38.85900  8.06383
# 16184 2011-12-06 19:00:00   91752  1082596212     True  38.86517  8.05950
# 16185 2011-12-07 04:00:00   91752  1082596213     True  38.85900  8.06367
# 16186 2011-12-07 07:00:00   91752  1082596214     True  38.86533  8.06000
# ...                   ...     ...         ...      ...       ...      ...
# 17076 2012-07-16 19:00:00   91752  1082597104     True  38.85567  8.06283
# 17077 2012-07-17 04:00:00   91752  1082597105     True  38.84850  8.03200
# 17078 2012-07-17 07:00:00   91752  1082597106     True  38.85550  8.06300
# 17079 2012-07-17 13:00:00   91752  1082597107     True  38.84433  8.06267
# ...
# ...                   ...     ...         ...      ...       ...       ...
# 85374 2012-11-17 19:00:00   91916  1082629607     True  39.18400  21.17217
# 85375 2012-11-18 04:00:00   91916  1082629608     True  39.17617  21.14183
# 85376 2012-11-18 07:00:00   91916  1082629609     True  39.17550  21.14217
# 85377 2012-11-18 13:00:00   91916  1082629610     True  39.18483  21.17250
# 85378 2012-11-18 19:00:00   91916  1082629611     True  39.18400  21.17250
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 84481         gps                    Larus fuscus                      91916A
# 84482         gps                    Larus fuscus                      91916A
# 84483         gps                    Larus fuscus                      91916A
# 84484         gps                    Larus fuscus                      91916A
# 84485         gps                    Larus fuscus                      91916A
# ...           ...                             ...                         ...
# 85374         gps                    Larus fuscus                      91916A
# 85375         gps                    Larus fuscus                      91916A
# 85376         gps                    Larus fuscus                      91916A
# 85377         gps                    Larus fuscus                      91916A
# 85378         gps                    Larus fuscus                      91916A
#
#                                               study-name
# 84481  Navigation experiments in lesser black-backed ...
# 84482  Navigation experiments in lesser black-backed ...
# 84483  Navigation experiments in lesser black-backed ...
# 84484  Navigation experiments in lesser black-backed ...
# 84485  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 85374  Navigation experiments in lesser black-backed ...
# 85375  Navigation experiments in lesser black-backed ...
# 85376  Navigation experiments in lesser black-backed ...
# 85377  Navigation experiments in lesser black-backed ...
# 85378  Navigation experiments in lesser black-backed ...
#
# [898 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 85379 2012-11-19 04:00:00   91916  1082629612     True  39.17083  21.16233
# 85380 2012-11-19 07:00:00   91916  1082629613     True  39.17100  21.15467
# 85381 2012-11-19 13:00:00   91916  1082629614     True  39.16900  21.15583
# 85382 2012-11-19 19:00:00   91916  1082629615     True  39.18400  21.17300
# 85383 2012-11-20 04:00:00   91916  1082629616     True  39.17433  21.14400
# ...                   ...     ...         ...      ...       ...       ...
# 86272 2013-07-06 05:00:00   91916  1082630505     True  24.31083  61.39133
# 86273 2013-07-06 08:00:00   91916  1082630506     True  23.97967  61.54200
# 86274 2013-07-06 14:00:00   91916  1082630507     True  24.37817  61.35083
# 86275 2013-07-06 20:00:00   91916  1082630508     True  24.37717  61.35050
# 86276 2013-07-07 05:00:00   91916  1082630509     True  24.15100  61.41317
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 85379         gps                    Larus fuscus                      91916A
# 85380         gps                    Larus fuscus                      91916A
# 85381         gps                    Larus fuscus                      91916A
# 85382         gps                    Larus fuscus                      91916A
# 85383         gps                    Larus fuscus                      91916A
# ...           ...                             ...                         ...
# 86272         gps                    Larus fuscus                      91916A
# 86273         gps                    Larus fuscus                      91916A
# 86274         gps                    Larus fuscus                      91916A
# 86275         gps                    Larus fuscus                      91916A
# 86276         gps                    Larus fuscus                      91916A
#
#                                               study-name
# 85379  Navigation experiments in lesser black-backed ...
# 85380  Navigation experiments in lesser black-backed ...
# 85381  Navigation experiments in lesser black-backed ...
# 85382  Navigation experiments in lesser black-backed ...
# 85383  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 86272  Navigation experiments in lesser black-backed ...
# 86273  Navigation experiments in lesser black-backed ...
# 86274  Navigation experiments in lesser black-backed ...
# 86275  Navigation experiments in lesser black-backed ...
# 86276  Navigation experiments in lesser black-backed ...
#
# [898 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 86277 2013-07-07 08:00:00   91916  1082630510     True  23.98500  61.54133
# 86278 2013-07-07 14:00:00   91916  1082630511     True  24.37783  61.35067
# 86279 2013-07-07 20:00:00   91916  1082630512     True  24.37783  61.35083
# 86280 2013-07-08 05:00:00   91916  1082630513     True  24.37800  61.35083
# 86281 2013-07-08 08:00:00   91916  1082630514     True  23.98050  61.54150
# ...                   ...     ...         ...      ...       ...       ...
# 87170 2014-02-17 04:00:00   91916  1082631403     True  39.03000  21.83483
# 87171 2014-02-17 07:00:00   91916  1082631404     True  39.00800  21.82583
# 87172 2014-02-17 13:00:00   91916  1082631405     True  39.02200  21.84017
# 87173 2014-02-17 19:00:00   91916  1082631406     True  39.01817  21.85383
# 87174 2014-02-18 04:00:00   91916  1082631407     True  39.06450  21.83750
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 86277         gps                    Larus fuscus                      91916A
# 86278         gps                    Larus fuscus                      91916A
# 86279         gps                    Larus fuscus                      91916A
# 86280         gps                    Larus fuscus                      91916A
# 86281         gps                    Larus fuscus                      91916A
# ...           ...                             ...                         ...
# 87170         gps                    Larus fuscus                      91916A
# 87171         gps                    Larus fuscus                      91916A
# 87172         gps                    Larus fuscus                      91916A
# 87173         gps                    Larus fuscus                      91916A
# 87174         gps                    Larus fuscus                      91916A
#
#                                               study-name
# 86277  Navigation experiments in lesser black-backed ...
# 86278  Navigation experiments in lesser black-backed ...
# 86279  Navigation experiments in lesser black-backed ...
# 86280  Navigation experiments in lesser black-backed ...
# 86281  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 87170  Navigation experiments in lesser black-backed ...
# 87171  Navigation experiments in lesser black-backed ...
# 87172  Navigation experiments in lesser black-backed ...
# 87173  Navigation experiments in lesser black-backed ...
# 87174  Navigation experiments in lesser black-backed ...
#
# [898 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 87175 2014-02-18 07:00:00   91916  1082631408     True  39.11017  21.67233
# 87176 2014-02-18 13:00:00   91916  1082631409     True  39.09417  21.67267
# 87177 2014-02-18 19:00:00   91916  1082631410     True  39.01850  21.85333
# 87178 2014-02-19 04:00:00   91916  1082631411     True  39.00783  21.83783
# 87179 2014-02-19 07:00:00   91916  1082631412     True  39.08917  21.61117
# ...                   ...     ...         ...      ...       ...       ...
# 88068 2014-10-08 05:00:00   91916  1082632301     True  35.52433  33.90833
# 88069 2014-10-08 08:00:00   91916  1082632302     True  35.52250  33.90850
# 88070 2014-10-08 14:00:00   91916  1082632303     True  35.52200  33.90817
# 88071 2014-10-08 20:00:00   91916  1082632304     True  35.53233  33.91550
# 88072 2014-10-09 05:00:00   91916  1082632305     True  35.52083  33.90750
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 87175         gps                    Larus fuscus                      91916A
# 87176         gps                    Larus fuscus                      91916A
# 87177         gps                    Larus fuscus                      91916A
# 87178         gps                    Larus fuscus                      91916A
# 87179         gps                    Larus fuscus                      91916A
# ...           ...                             ...                         ...
# 88068         gps                    Larus fuscus                      91916A
# 88069         gps                    Larus fuscus                      91916A
# 88070         gps                    Larus fuscus                      91916A
# 88071         gps                    Larus fuscus                      91916A
# 88072         gps                    Larus fuscus                      91916A
#
#                                               study-name
# 87175  Navigation experiments in lesser black-backed ...
# 87176  Navigation experiments in lesser black-backed ...
# 87177  Navigation experiments in lesser black-backed ...
# 87178  Navigation experiments in lesser black-backed ...
# 87179  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 88068  Navigation experiments in lesser black-backed ...
# 88069  Navigation experiments in lesser black-backed ...
# 88070  Navigation experiments in lesser black-backed ...
# 88071  Navigation experiments in lesser black-backed ...
# 88072  Navigation experiments in lesser black-backed ...
#
# [898 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 88073 2014-10-09 08:00:00   91916  1082632306     True  35.52117  33.90783
# 88074 2014-10-09 14:00:00   91916  1082632307     True  35.40700  33.79167
# 88075 2014-10-09 20:00:00   91916  1082632308     True  34.75917  32.21800
# 88076 2014-10-10 05:00:00   91916  1082632309     True  34.28717  31.39033
# 88077 2014-10-10 08:00:00   91916  1082632310     True  34.19450  31.30567
# ...                   ...     ...         ...      ...       ...       ...
# 88966 2015-05-22 14:00:00   91916  1082633199     True  24.37817  61.35083
# 88967 2015-05-22 20:00:00   91916  1082633200     True  24.37817  61.35083
# 88968 2015-05-23 05:00:00   91916  1082633201     True  24.37800  61.35067
# 88969 2015-05-23 08:00:00   91916  1082633202     True  24.37833  61.35067
# 88970 2015-05-23 14:00:00   91916  1082633203     True  24.17283  61.43450
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 88073         gps                    Larus fuscus                      91916A
# 88074         gps                    Larus fuscus                      91916A
# 88075         gps                    Larus fuscus                      91916A
# 88076         gps                    Larus fuscus                      91916A
# 88077         gps                    Larus fuscus                      91916A
# ...           ...                             ...                         ...
# 88966         gps                    Larus fuscus                      91916A
# 88967         gps                    Larus fuscus                      91916A
# 88968         gps                    Larus fuscus                      91916A
# 88969         gps                    Larus fuscus                      91916A
# 88970         gps                    Larus fuscus                      91916A
#
#                                               study-name
# 88073  Navigation experiments in lesser black-backed ...
# 88074  Navigation experiments in lesser black-backed ...
# 88075  Navigation experiments in lesser black-backed ...
# 88076  Navigation experiments in lesser black-backed ...
# 88077  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 88966  Navigation experiments in lesser black-backed ...
# 88967  Navigation experiments in lesser black-backed ...
# 88968  Navigation experiments in lesser black-backed ...
# 88969  Navigation experiments in lesser black-backed ...
# 88970  Navigation experiments in lesser black-backed ...
#
# [898 rows x 10 columns]
#                  DateTime traj_id    event-id  visible       lon       lat  \
# 88971 2015-05-23 20:00:00   91916  1082633204     True  24.37817  61.35083
# 88972 2015-05-24 05:00:00   91916  1082633205     True  24.37800  61.35100
# 88973 2015-05-24 08:00:00   91916  1082633206     True  24.17400  61.40733
# 88974 2015-05-24 14:00:00   91916  1082633207     True  24.37800  61.35100
# 88975 2015-05-24 20:00:00   91916  1082633208     True  24.37817  61.35083
# ...                   ...     ...         ...      ...       ...       ...
# 89864 2009-08-29 14:00:00   91930  1082710935     True  35.67700  65.03150
# 89865 2009-08-29 20:00:00   91930  1082710936     True  35.69533  65.02683
# 89866 2009-08-30 05:00:00   91930  1082710937     True  35.67967  65.03167
# 89867 2009-08-30 08:00:00   91930  1082710938     True  35.69700  65.02917
# 89868 2009-08-31 05:00:00   91930  1082710939     True  35.72717  65.01700
#
#       sensor-type individual-taxon-canonical-name individual-local-identifier  \
# 88971         gps                    Larus fuscus                      91916A
# 88972         gps                    Larus fuscus                      91916A
# 88973         gps                    Larus fuscus                      91916A
# 88974         gps                    Larus fuscus                      91916A
# 88975         gps                    Larus fuscus                      91916A
# ...           ...                             ...                         ...
# 89864         gps                    Larus fuscus                      91930A
# 89865         gps                    Larus fuscus                      91930A
# 89866         gps                    Larus fuscus                      91930A
# 89867         gps                    Larus fuscus                      91930A
# 89868         gps                    Larus fuscus                      91930A
#
#                                               study-name
# 88971  Navigation experiments in lesser black-backed ...
# 88972  Navigation experiments in lesser black-backed ...
# 88973  Navigation experiments in lesser black-backed ...
# 88974  Navigation experiments in lesser black-backed ...
# 88975  Navigation experiments in lesser black-backed ...
# ...                                                  ...
# 89864  Navigation experiments in lesser black-backed ...
# 89865  Navigation experiments in lesser black-backed ...
# 89866  Navigation experiments in lesser black-backed ...
# 89867  Navigation experiments in lesser black-backed ...
# 89868  Navigation experiments in lesser black-backed ...
#
# [898 rows x 10 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Desktop/NumMobility/features/temporal_features.py in create_time_column(dataframe)
#     116         # Then, calculate the result on each separate part in parallel and store it in
#     117         # the result variable which is of type Mapper.
# --> 118         pool = multiprocessing.Pool(len(df_chunks))
#     119         result = pool.map(helpers._time_helper, df_chunks)
#     120
#
# TypeError: object of type 'NoneType' has no len()

# %%
# %%time

# Now, let's calculate the time duration.
delta_one = temporal.get_traj_duration(dataframe)
delta_two = temporal.get_traj_duration(dataframe, traj_id='5')
delta_one
# Out:
# CPU times: user 73.8 ms, sys: 4.12 ms, total: 77.9 ms
# Wall time: 77.3 ms
# Timedelta('146 days 23:53:26')

# %%
# %%time

# Now, lets get the starting time of all the trajectory IDs.
temporal.get_start_time(gulls)
# Out:
# CPU times: user 80.7 ms, sys: 13.5 ms, total: 94.1 ms
# Wall time: 1.49 s
#                    DateTime
# traj_id
# 91732   2009-05-27 14:00:00
# 91733   2009-08-15 15:00:00
# 91734   2009-05-25 00:05:00
# 91735   2009-05-27 14:00:00
# 91737   2009-07-26 05:00:00
# ...                     ...
# 91920   2009-08-19 19:00:00
# 91921   2009-08-19 19:00:00
# 91924   2009-08-19 19:00:00
# 91929   2009-08-19 19:00:00
# 91930   2009-08-19 05:00:00
#
# [126 rows x 1 columns]

# %%
# %%time

# Now, lets get the ending time of a specific trajectory ID.
temporal.get_end_time(gulls, '91732')
# Out:
# CPU times: user 28 ms, sys: 6.99 ms, total: 35 ms
# Wall time: 34.3 ms
# Timestamp('2010-10-28 14:00:00')
